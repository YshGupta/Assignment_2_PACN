# %%
import pickle
from datetime import datetime

with open('ping_data.pkl', 'rb') as file:
    loaded_data = pickle.load(file)

# Access the loaded data
Names =loaded_data['Names']
Servers = loaded_data['Servers']
Times = loaded_data['Times']
Delays = loaded_data['Delays']
Throughputs = loaded_data['Throughputs']

# dt_object = datetime.utcfromtimestamp(Times[0][0])
# print(dt_object.minute)

print(len(Delays[0]))
Names[1] = "Bell Teleservices India Pvt. Ltd."
# Out:
# 100

# %%
human_readable_times = []
ls1 = [datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S') for ts in Times[0]]
ls2 = [datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S') for ts in Times[1]]
ls3 = [datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S') for ts in Times[2]]

human_readable_times.append(ls1)
human_readable_times.append(ls2)
human_readable_times.append(ls3)

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt



# Standardize the data
scaler = StandardScaler()

for i in range(3):
    plt.figure(figsize=(15, 8)) 

    delay = Delays[i]
    times = Times[i]
    throughput = Throughputs[i]
    selected_dates = human_readable_times[i][::N]

    delay_standardized = scaler.fit_transform([[d] for d in delay])
    throughput_standardized = scaler.fit_transform([[t] for t in throughput])
    
    # Plot the standardized data
    plt.plot(human_readable_times[i], delay_standardized, label="Time  Delay")
    plt.plot(human_readable_times[i], throughput_standardized, label="Standardized Throughput")
    plt.xticks(selected_dates, rotation=0)
    plt.title(f"Time vs Standardized Delay and Throughput for {Names[i]}")
    plt.legend()
    plt.show()
    print()
    print()

# %%
import numpy as np
for i in range(3):
    # Plot the standardized data
    # Sort throughputs_i and rearrange delays_

    
    throughputs_i = Throughputs[i]
    delays_i = Delays[i]
    sorted_indices = np.argsort(throughputs_i)
    sorted_throughputs_i = np.sort(throughputs_i)
    sorted_delays_i = [delays_i[i] for i in sorted_indices]
    plt.scatter(sorted_throughputs_i , sorted_delays_i , marker = 'o' , color = 'b')

    plt.plot(sorted_throughputs_i , sorted_delays_i , color = 'r')
    plt.title(f"Delay vs Throughput for {Names[i]}")
    plt.show()
